# %% [markdown]
# # NLP Information Extraction: Data Exploration

# %% [markdown]
# ### Введение
# В Контуре мы много работаем с документами: арбитражные иски, госзакупки, исполнительные производства. В данном задании мы предлагаем вам сделать модель, которая поможет отделу госзакупок извлекать
# нужный кусок текста из документа для того, чтобы сформировать анкету заявки. То, какой именно фрагмент текста нужно извлечь, зависит от пункта анкеты, соответствующего документу.
# Всего в каждом документе, с которыми вы будет работать, есть 1 из 2-х пунктов анкеты, по которым необходимо извлекать кусочки из текста:
# - обеспечение исполнения контракта
# - обеспечение гарантийных обязательств
#
# Соответственно, ваша модель, принимая на вход `текст документа` и `наименование одного из двух пунктов`, должна возвращать `соответствующий кусочек текста из текста документа`.
#
# ### Данные
#
# ##### train.json
# Данные для обучения в формате json имеют следующие поля:
# - `id`: int - id документа
# -  `text`: str - текст документа, в котором может содержаться фрагмент текста, соответствующий пункту анкеты из поля `label`
# - `label`: str - название пункта анкеты. Может принимать одно из двух значений: `обеспечение исполнения контракта` или `обеспечение гарантийных обязательств`
# - `extracted_part`: dict следующего формата:
# ```
#     {
#         'text': [фрагмент текста из поля `text`, соответствующий пункту анкеты],
#         'answer_start': [индекс символа начала фрагмента текста в тексте документа],
#         'answer_end': [индекс символа конца фрагмента текста в тексте документа]
#     }
# ```
#
# ##### test.json
#
# Для демонстрации работы модели используйте данные из файла `test.json`. В нем есть все те же поля, что и в файле `train.json`, кроме поля `extracted_part` - именно его вам и нужно будет добавить,
# для того, чтобы мы смогли оценить качество вашей модели.
#
# ### Тестовое задание
#
# Для выполнения тестового задания требуется разработать модель, которая будет способна по паре `текст документа` и `пункт анкеты` извлекать из текста документа нужный фрагмент текста.
# Обучив модель, добавьте в файл `test.json` поле `extracted_part` в том же формате, что и в файле `train.json`. Новый файл назовите `predictions.json`
#
# **Подсказка**: изучив данные, вы можете заметить, что у части наблюдений отсутствует фрагмент текста к извлечению (пустая строка внутри поля `extracted_part` с `answer_start` и
# `answer_end` равными нулю). Это означает, что в тексте документа нет нужного фрагмента текста, соответствующего пункту анкеты. Учтите это в обучении вашей модели и при формировании
# файла с ответами.
#
# ### Критерии оценки
# 1. Для оценки финального решения будет использоваться метрика `Accuracy`: доля наблюдений, в которых извлеченный моделью фрагмент текста полностью соответствует фактически
#    требуемому фрагменту.
# 2. Чистота кода, оформление и понятность исследования.
#
# ### Требования к решению
# В качестве решения мы ожидаем zip-архив со всеми *.py и *.ipynb файлами в папке solution и файлом `predictions.json` в корне. Формат имени zip-архива: LastName_FirstName.zip (пример Ivanov_Ivan.zip).
# Файл `predictions.json` должен включать в себя колонки `id`, `text`, `label`, содержащие те же данные, что и исходный файл `test.json`, а также колонку `extracted_part` в том же
# формате, что и в файле `train.json`
# Разметка тестового набора данных и включение его в обучение/валидацию запрещены.
#
# В папке solution должно быть отражено исследование и весь код, необходимый для воспроизведения исследования.
#
# Успехов!

# %%
from tqdm import tqdm, trange
from pprint import pprint
import pandas as pd
import numpy as np
import json
import re
import random
import torch
import gc

# %%
with open(f'{DATA_DIR}/train.json', 'rb') as f:
    train = json.load(f)
with open(f'{DATA_DIR}/test.json', 'rb') as f:
    test = json.load(f)

# %%
LABELS = {
    'обеспечение исполнения контракта': {
        'short': 'CE',
        'full': 'CONTRACT-ENFORCEMENT',
        'id': 1,
        'emb': [],
        'emb_tuned': [],
        'regex_pattern': r'',
    },
    'обеспечение гарантийных обязательств': {
        'short': 'WO',
        'full': 'WARRANTY-OBLIGRATIONS',
        'id': 2,
        'emb': [],
        'emb_tuned': [],
        'regex_pattern': r'',
    },
}
LABELS_INV = {
    'CE': 'обеспечение исполнения контракта',
    'WO': 'обеспечение гарантийных обязательств',
}

# %%
EMB_DIM = 300  # natasha

# %% [markdown]
# ## Data samples

# %%
pprint(train[1701])
# Out:
# {'extracted_part': {'answer_end': [1410],
#                     'answer_start': [1225],
#                     'text': ['Размер обеспечения гарантийных обязательств '
#                              'установлен в размере 20% от НМЦД: 1 644 839,76 '
#                              'рублей. Гарантийные обязательства обеспечиваются '
#                              'внесением денежных средств участником закупки']},
#  'id': 611794687,
#  'label': 'обеспечение гарантийных обязательств',
#  'text': 'УТВЕРЖДАЮ Генеральный директор АО «САБ по уборке г. Курска» «07» '
#          'сентября 2022 г. _____________________ А.Р. Зинатулин М.П. '
#          'ДОКУМЕНТАЦИЯ ОБ АУКЦИОНЕ В ЭЛЕКТРОННОЙ ФОРМЕ, УЧАСТНИКАМИ КОТОРОГО '
#          'МОГУТ БЫТЬ ТОЛЬКО СУБЪЕКТЫ МАЛОГО  5 апреля 2013 года N 44-ФЗ "О '
#          'контрактной системе в сфере закупок товаров, работ, услуг для '
#          'обеспечения государственных и муниципальных нужд". 54. Требования к '
#          'участникам такой закупки и привлекаемым ими субподрядчикам, '
#          'соисполнителям и (или) изготовителям товара, являющегося предметом '
#          'закупки, и перечень документов, представляемых участниками такой '
#          'закупки для подтверждения их соответствия указанным требованиям, в '
#          'случае закупки работ по проектированию, строительству, модернизации '
#          'и ремонту особо опасных, технически сложных объектов капитального '
#          'строительства и закупки товаров, работ, услуг, связанных с '
#          'использованием атомной энергии Не установлено 55. Размер обеспечения '
#          'исполнения договора, порядок предоставления такого обеспечения, '
#          'требования к такому обеспечению. Обеспечение гарантийных '
#          'обязательств В целях обеспечения исполнения обязательств по Договору '
#          'участник закупки предоставляет Заказчику обеспечение исполнения '
#          'Договора. Размер обеспечения исполнения договора не установлен. '
#          'Размер обеспечения гарантийных обязательств установлен в размере 20% '
#          'от НМЦД: 1 644 839,76 рублей. Гарантийные обязательства '
#          'обеспечиваются внесением денежных средств участником закупки на '
#          'указанный заказчиком счет, на котором в соответствии с '
#          'законодательством Российской Федерации учитываются операции со '
#          'средствами, поступающими заказчику. Договор заключается после '
#          'предоставления участником закупки, с которым заключается договор, '
#          'обеспечения гарантийных обязательств, предоставляемые вместе с '
#          'обеспечением исполнения договора. При непредоставлении обеспечения '
#          'гарантийных обязательств договор не заключается. В ходе исполнения '
#          'договора подрядчик не вправе изменить способ обеспечения исполнения '
#          'гарантийных обязательств. Внесение денежных средств осуществляется '
#          'по следующим банковским реквизитам для внесения обеспечения '
#          'договора: Получатель: Акционерное общество «Спецавтобаза по уборке '
#          'города Курска», сокращенное наименование: АО «САБ по уборке г. '
#          'Курска» Название Банка: Курское отделение № 8596 ПАО Сбербанк БИК: '
#          '043807606 р/с: 40702810433000002123 к/с: 30101810300000000606 В '
#          'назначении платежа указать: обеспечение гарантийных обязательств по '
#          'закупке «Выполнение земляных  21'}

# %%
pprint(test[0])
# Out:
# {'id': 762883279,
#  'label': 'обеспечение исполнения контракта',
#  'text': 'МУНИЦИПАЛЬНЫЙ КОНТРАКТ № ______ на оказание услуг по техническому '
#          'обслуживанию и ремонту принтеров и многофункциональных устройств, '
#          'заправке и восстановлению картриджей (идентификационный код закупки '
#          '223861800296886010100100590019511244) г. Ханты-Мансийск «___» '
#          '____________ 2022 г.  (или) возмещения убытков причинённых '
#          'Исполнителем убытков. 6. Обеспечение исполнения контракта 6.1. '
#          'Исполнение контракта обеспечиваются предоставлением независимой '
#          'гарантии, выданной банком и соответствующей требованиям Федерального '
#          'закона от 05.04.2013 № 44-ФЗ «О контрактной системе в сфере закупок '
#          'товаров, работ, услуг для обеспечения государственных и '
#          'муниципальных нужд», или внесением денежных средств на указанный '
#          'заказчиком счет, на котором в соответствии с законодательством '
#          'Российской Федерации учитываются операции со средствами, '
#          'поступающими заказчику. Способ обеспечения исполнения контракта, '
#          'срок действия независимой гарантии определяются в соответствии с '
#          'требованиями Федерального закона от 05.04.2013 № 44-ФЗ «О '
#          'контрактной системе в сфере закупок товаров, работ, услуг для '
#          'обеспечения государственных и муниципальных нужд» участником '
#          'закупки, с которым заключается контракт, самостоятельно. 6.2. '
#          'Обеспечение исполнения Контракта предоставляется Заказчику до '
#          'заключения Контракта. Размер обеспечения исполнения Контракта '
#          'составляет _______ рублей ____ копеек (5 процентов от цены '
#          'контракта). Получатель: Комитет по финансам администрации '
#          'Ханты-Мансийского района (Администрация Ханты-Мансийского района, '
#          'л/сч 040.01.001.2) ИНН 8618002968 КПП 860101001 Банк плательщика: '
#          'РКЦ Ханты-Мансийск//УФК по Ханты-Мансийскому автономному округу – '
#          'Югре г. Ханты-Мансийск, ЕКС 40102810245370000007 БИК 007162163 '
#          'Казначейский счет 03232643718290008700 В случае заключения контракта '
#          'по результатам определения Исполнителя в соответствии с пунктом 1 '
#          'части 1 статьи 30 Федерального закона от 05.04.2013 № 44-ФЗ «О '
#          'контрактной системе в сфере закупок товаров, работ, услуг для '
#          'обеспечения государственных и муниципальных нужд» размер обеспечения '
#          'исполнения контракта, в том числе предоставляемого с учетом '
#          'положений статьи 37 Федерального закона от 05.04.2013 № 44-ФЗ «О '
#          'контрактной системе в сфере закупок товаров, работ, услуг для '
#          'обеспечения государственных и муниципальных нужд», устанавливается '
#          'от цены, по которой в соответствии с Федерального закона от '
#          '05.04.2013 № 44-ФЗ «О контрактной системе в сфере 13.Адреса места '
#          'нахождения, банковские реквизиты и подписи Сторон ЗАКАЗЧИК: '
#          'Администрация Ханты-Мансийского района Юридический адрес: 628011, '
#          'Тюменская область, Ханты-Мансийский автономный округ - Югра, г. '
#          'Ханты-Мансийск, ул. Гагарина, 214 Почтовый адрес: 628011,'}

# %% [markdown]
# ## Analysis of extracted parts

# %%
for i, d in enumerate(train):
    d_text = d['text']
    e_text = d['extracted_part']['text'][0]
    answer_start = d['extracted_part']['answer_start'][0]
    answer_end = d['extracted_part']['answer_end'][0]
    padding = 5
    if e_text:
        print(f'[{i}] doc: {d_text[answer_start-padding:answer_end+padding]}')
        print(f'[{i}] txt: {" "*padding}{e_text}{" "*padding}')
# Out:
# [0] doc: акта Размер обеспечения исполнения контракта 6593.25 Российский рубль Поря
# [0] txt:      Размер обеспечения исполнения контракта 6593.25 Российский рубль
# [1] doc: 005. Поставщик должен предоставить обеспечение исполнения контракта в размере 10 % от цены Контракта. В сл
# [1] txt:      Поставщик должен предоставить обеспечение исполнения контракта в размере 10 % от цены Контракта.
# [2] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [2] txt:      Размер обеспечения исполнения контракта 10.00%
# [3] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [3] txt:      Размер обеспечения исполнения контракта 10.00%
# [4] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [4] txt:      Размер обеспечения исполнения контракта 10.00%
# [5] doc: 7.4. Размер обеспечения исполнения контракта устанавливается в размере 5 (пять) процентов от цены, по которой заключается контракт и составляет ________
# [5] txt:      Размер обеспечения исполнения контракта устанавливается в размере 5 (пять) процентов от цены, по которой заключается контракт и составляет ___
# [6] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [6] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [7] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [7] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [8] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [8] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [9] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [9] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [10] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [10] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [11] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [11] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [12] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [12] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [13] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [13] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [14] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [14] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [15] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [15] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [16] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [16] txt:      Размер обеспечения исполнения контракта 10.00%
# [17] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [17] txt:      Размер обеспечения исполнения контракта 5.00%
# [18] doc: ьно. Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % от начальной (максимальной) цены Контракта, что
# [18] txt:      Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % от начальной (максимальной) цены Контракта
# [19] doc: акта Размер обеспечения исполнения контракта 11635.97 Российский рубль Поря
# [19] txt:      Размер обеспечения исполнения контракта 11635.97 Российский рубль
# [20] doc: 9.1. Обеспечение исполнения Контракта устанавливается в размере 5 процентов от Цены Контракта. 9.2.
# [20] txt:      Обеспечение исполнения Контракта устанавливается в размере 5 процентов от Цены Контракта.
# [21] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [21] txt:      Размер обеспечения исполнения контракта 5.00%
# [22] doc: акта Размер обеспечения исполнения контракта 1.00% Поря
# [22] txt:      Размер обеспечения исполнения контракта 1.00%
# [23] doc: 1.1. Размер обеспечения исполнения контракта составляет 10 (Десять) процентов цены контракта, что составляет _____ рублей. 7.1.
# [23] txt:      Размер обеспечения исполнения контракта составляет 10 (Десять) процентов цены контракта, что составляет _____ рублей.
# [24] doc: акта Размер обеспечения исполнения контракта 1239.41 Российский рубль Поря
# [24] txt:      Размер обеспечения исполнения контракта 1239.41 Российский рубль
# [25] doc: 8.1. Обеспечение исполнения контракта устанавливается в размере 5% цены, по которой заключается контракт. Банк
# [25] txt:      Обеспечение исполнения контракта устанавливается в размере 5% цены, по которой заключается контракт.
# [26] doc: тся. Исполнитель внес обеспечение исполнения Контракта в размере ___ , что составляет 5 % Цены Контракта в форме безотзывной независимой гарантии/путе
# [26] txt:      Исполнитель внес обеспечение исполнения Контракта в размере ___ , что составляет 5 % Цены Контракта в форме безотзывной независимой гарантии
# [27] doc: акта Размер обеспечения исполнения контракта: 1% от цены контакта 14.1
# [27] txt:      Размер обеспечения исполнения контракта: 1% от цены контакта
# [28] doc: акта Размер обеспечения исполнения контракта составляет 5% от цены контракта. В то
# [28] txt:      Размер обеспечения исполнения контракта составляет 5% от цены контракта.
# [29] doc: 0.1. Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5,00 % от цены Контракта. В сл
# [29] txt:      Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5,00 % от цены Контракта.
# [30] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [30] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [31] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [31] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [32] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [32] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [33] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [33] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [34] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [34] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [35] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [35] txt:      Размер обеспечения исполнения контракта 5.00%
# [36] doc: -ФЗ) Размер обеспечения исполнения контракта (договора) составляет: 0,50% от цены, по
# [36] txt:      Размер обеспечения исполнения контракта (договора) составляет: 0,50% от цены
# [37] doc: акта Размер обеспечения исполнения контракта 5018.47 Российский рубль Поря
# [37] txt:      Размер обеспечения исполнения контракта 5018.47 Российский рубль
# [38] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [38] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [39] doc: 8.1. Обеспечение исполнения настоящего Контракта установлено в размере 5,00% от цены контракта, а именно _______ рублей ____копеек. 8.2.
# [39] txt:      Обеспечение исполнения настоящего Контракта установлено в размере 5,00% от цены контракта, а именно _______ рублей ____копеек.
# [40] doc: акта Размер обеспечения исполнения контракта 1436.40 Российский рубль Поря
# [40] txt:      Размер обеспечения исполнения контракта 1436.40 Российский рубль
# [41] doc: 7.1. Обеспечение исполнения настоящего Контракта устанавливается в размере 5 % (пять процентов) от начальной (максимальной) цены Контракта, что
# [41] txt:      Обеспечение исполнения настоящего Контракта устанавливается в размере 5 % (пять процентов) от начальной (максимальной) цены Контракта
# [42] doc: 8.1. Обеспечение исполнения Контракта устанавливается в размере 5 % от цены, по которой заключается Контракт, что составляет _______
# [42] txt:      Обеспечение исполнения Контракта устанавливается в размере 5 % от цены, по которой заключается Контракт, что составляет __
# [43] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [43] txt:      Размер обеспечения исполнения контракта 10.00%
# [44] doc: акта Размер обеспечения исполнения контракта 8873.10 Российский рубль Поря
# [44] txt:      Размер обеспечения исполнения контракта 8873.10 Российский рубль
# [45] doc: 7.1. Обеспечение исполнения Контракта устанавливается в размере 0,5 % от цены Контракта, что составляет ___________ (____________) руб
# [45] txt:      Обеспечение исполнения Контракта устанавливается в размере 0,5 % от цены Контракта, что составляет ___________ (____________
# [46] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [46] txt:      Размер обеспечения исполнения контракта 10.00%
# [47] doc: акта Размер обеспечения исполнения контракта 21337.65 Российский рубль Поря
# [47] txt:      Размер обеспечения исполнения контракта 21337.65 Российский рубль
# [48] doc: акта Размер обеспечения исполнения контракта 249915.69 Российский рубль Поря
# [48] txt:      Размер обеспечения исполнения контракта 249915.69 Российский рубль
# [49] doc: 8.1. Поставщик при заключении Договора должен предоставить Заказчику обеспечение исполнения Договора в размере 1 % от цены Договора. В сл
# [49] txt:      Поставщик при заключении Договора должен предоставить Заказчику обеспечение исполнения Договора в размере 1 % от цены Договора.
# [50] doc: акта Размер обеспечения исполнения контракта 0.50% Поря
# [50] txt:      Размер обеспечения исполнения контракта 0.50%
# [51] doc: 2.9. Размер обеспечения исполнения контракта составляет 10% от цены контракта, по
# [51] txt:      Размер обеспечения исполнения контракта составляет 10% от цены контракта
# [52] doc: акта Сумма обеспечения контракта составляет 10 % от цены контракта Поря
# [52] txt:      Сумма обеспечения контракта составляет 10 % от цены контракта
# [53] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [53] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [54] doc: 0.1. Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % НМЦК. В сл
# [54] txt:      Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % НМЦК.
# [55] doc: 8.1. Принять к сведению, что Поставщик внес обеспечение исполнения контракта в размере 10,00% от цены контракта на сумму _________ рублей. 8.1.
# [55] txt:      Принять к сведению, что Поставщик внес обеспечение исполнения контракта в размере 10,00% от цены контракта на сумму _________ рублей.
# [56] doc: акта Размер обеспечения исполнения контракта 2.00% Поря
# [56] txt:      Размер обеспечения исполнения контракта 2.00%
# [57] doc: акта Размер обеспечения исполнения контракта 20.00% Поря
# [57] txt:      Размер обеспечения исполнения контракта 20.00%
# [58] doc: 8.1. Обеспечение исполнения контракта установлено в размере 5,00% от цены контракта на сумму _________ рублей. В сл
# [58] txt:      Обеспечение исполнения контракта установлено в размере 5,00% от цены контракта на сумму _________ рублей.
# [59] doc: акта Размер обеспечения исполнения контракта 1049760.00 Российский рубль Поря
# [59] txt:      Размер обеспечения исполнения контракта 1049760.00 Российский рубль
# [60] doc: 1.1. Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5% начальной (максимальной) цены контракта. В сл
# [60] txt:      Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5% начальной (максимальной) цены контракта.
# [61] doc: акта Размер обеспечения исполнения контракта 33353.10 Российский рубль Поря
# [61] txt:      Размер обеспечения исполнения контракта 33353.10 Российский рубль
# [62] doc: ьств Размер обеспечения гарантийных обязательств 1597.60 Российский рубль Поря
# [62] txt:      Размер обеспечения гарантийных обязательств 1597.60 Российский рубль
# [63] doc: акта Размер обеспечения исполнения контракта 29147.99 Российский рубль Поря
# [63] txt:      Размер обеспечения исполнения контракта 29147.99 Российский рубль
# [64] doc: 1.5. Заказчиком установлено требование обеспечения исполнения контракта в размере 10 процентов от цены контракта, что составляет: _______________________. По
# [64] txt:      Заказчиком установлено требование обеспечения исполнения контракта в размере 10 процентов от цены контракта, что составляет: ______________________
# [65] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [65] txt:      Размер обеспечения исполнения контракта 10.00%
# [66] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [66] txt:      Размер обеспечения исполнения контракта 5.00%
# [67] doc: 8.2. Размер обеспечения исполнения Контракта составляет 5% (пять процентов) от цены Контракта, что составляет ___________ ( ) рублей копе
# [67] txt:      Размер обеспечения исполнения Контракта составляет 5% (пять процентов) от цены Контракта, что составляет ___________ ( ) рублей
# [68] doc: акта Размер обеспечения исполнения Контракта составляет 10 % от начальной (максимальной) цены Контракта. 11 П
# [68] txt:      Размер обеспечения исполнения Контракта составляет 10 % от начальной (максимальной) цены Контракта.
# [69] doc: акта Размер обеспечения исполнения контракта: 5 % от цены контракта, по которой заключается контракт. 12.1
# [69] txt:      Размер обеспечения исполнения контракта: 5 % от цены контракта, по которой заключается контракт.
# [70] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [70] txt:      Размер обеспечения исполнения контракта 5.00%
# [71] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [71] txt:      Размер обеспечения исполнения контракта 10.00%
# [72] doc: 9.1. Подрядчиком представлено обеспечение исполнения Контракта в виде _______________________________ в размере 10% от начальной (максимальной) цены Контракта что
# [72] txt:      Подрядчиком представлено обеспечение исполнения Контракта в виде _______________________________ в размере 10% от начальной (максимальной) цены Контракта
# [73] doc: акта Размер обеспечения исполнения контракта 31135.75 Российский рубль Поря
# [73] txt:      Размер обеспечения исполнения контракта 31135.75 Российский рубль
# [74] doc: 10.1.Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10 % начальной (максимальной) цены контракта – 10 080,00 руб. 10.2
# [74] txt:      Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10 % начальной (максимальной) цены контракта – 10 080,00 руб.
# [75] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [75] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [76] doc: акта Размер обеспечения исполнения контракта 2250.00 Российский рубль Поря
# [76] txt:      Размер обеспечения исполнения контракта 2250.00 Российский рубль
# [77] doc: акта Размер обеспечения исполнения контракта 5278.00 Российский рубль Поря
# [77] txt:      Размер обеспечения исполнения контракта 5278.00 Российский рубль
# [78] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [78] txt:      Размер обеспечения исполнения контракта 10.00%
# [79] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [79] txt:      Размер обеспечения исполнения контракта 5.00%
# [80] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [80] txt:      Размер обеспечения исполнения контракта 5.00%
# [81] doc: акта Размер обеспечения исполнения контракта 0.50% Поря
# [81] txt:      Размер обеспечения исполнения контракта 0.50%
# [82] doc: акта Размер обеспечения исполнения контракта 7525.67 Российский рубль Поря
# [82] txt:      Размер обеспечения исполнения контракта 7525.67 Российский рубль
# [83] doc: . 15 Размер обеспечения исполнения контракта: 10% от начальной (максимальной) цены Контракта. Учас
# [83] txt:      Размер обеспечения исполнения контракта: 10% от начальной (максимальной) цены Контракта.
# [84] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [84] txt:      Размер обеспечения исполнения контракта 10.00%
# [85] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [85] txt:      Размер обеспечения исполнения контракта 10.00%
# [86] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [86] txt:      Размер обеспечения исполнения контракта 5.00%
# [87] doc: тся. Поставщик внес обеспечение исполнения Контракта в размере __ , что составляет 5 % Цены
# [87] txt:      Поставщик внес обеспечение исполнения Контракта в размере __ , что составляет 5 %
# [88] doc: акта Размер обеспечения исполнения контракта 20877.84 Российский рубль Поря
# [88] txt:      Размер обеспечения исполнения контракта 20877.84 Российский рубль
# [89] doc: акта Размер обеспечения исполнения контракта 98606.87 Российский рубль Поря
# [89] txt:      Размер обеспечения исполнения контракта 98606.87 Российский рубль
# [90] doc: 9.1. Обеспечение исполнения Контракта устанавливается в размере 5 процентов от начальной (максимальной) цены контракта. 9.2.
# [90] txt:      Обеспечение исполнения Контракта устанавливается в размере 5 процентов от начальной (максимальной) цены контракта.
# [91] doc: акта Размер обеспечения исполнения контракта 1.00% Поря
# [91] txt:      Размер обеспечения исполнения контракта 1.00%
# [92] doc: 7.1. Обеспечение исполнения Контракта составляет 10% от цены Контракта(цены лота),что составляет_________ (__________
# [92] txt:      Обеспечение исполнения Контракта составляет 10% от цены Контракта(цены лота),что составляет_________ (_____
# [93] doc: 7.1. Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % от цены, по
# [93] txt:      Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % от цены
# [94] doc: 0.1. Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10% начальной (максимальной) цены контракта. В сл
# [94] txt:      Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10% начальной (максимальной) цены контракта.
# [95] doc: 2.1. Размер обеспечения гарантийных обязательств 1% начальной (максимальной) цены контракта, что составляет 3 150,00 рублей. 12.2
# [95] txt:      Размер обеспечения гарантийных обязательств 1% начальной (максимальной) цены контракта, что составляет 3 150,00 рублей.
# [96] doc: ению Размер обеспечения исполнения контракта составляет 10 (десять) процентов начальной (максимальной) цены контракта: 8 903 рублей 98 к
# [96] txt:      Размер обеспечения исполнения контракта составляет 10 (десять) процентов начальной (максимальной) цены контракта: 8 903 рублей
# [97] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [97] txt:      Размер обеспечения исполнения контракта 5.00%
# [98] doc: акта Размер обеспечения исполнения контракта 9523.60 Российский рубль Поря
# [98] txt:      Размер обеспечения исполнения контракта 9523.60 Российский рубль
# [99] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [99] txt:      Размер обеспечения исполнения контракта 10.00%
# [100] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [100] txt:      Размер обеспечения исполнения контракта 5.00%
# [101] doc: акта Размер обеспечения исполнения контракта 15.00% Поря
# [101] txt:      Размер обеспечения исполнения контракта 15.00%
# [102] doc: 8.2. Обеспечение гарантийных обязательств устанавливается в размере 5% процентов начальной (максимальной) цены контракта, что составляет 60 787 (шес
# [102] txt:      Обеспечение гарантийных обязательств устанавливается в размере 5% процентов начальной (максимальной) цены контракта, что составляет 60 787
# [103] doc: акта Размер обеспечения исполнения контракта 3354.78 Российский рубль Поря
# [103] txt:      Размер обеспечения исполнения контракта 3354.78 Российский рубль
# [104] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [104] txt:      Размер обеспечения исполнения контракта 5.00%
# [105] doc: акта Размер обеспечения исполнения контракта 1383.33 Российский рубль Поря
# [105] txt:      Размер обеспечения исполнения контракта 1383.33 Российский рубль
# [106] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [106] txt:      Размер обеспечения исполнения контракта 5.00%
# [107] doc: ьств Размер обеспечения гарантийных обязательств 11599.38 Российский рубль Поря
# [107] txt:      Размер обеспечения гарантийных обязательств 11599.38 Российский рубль
# [108] doc: ения таким участником обеспечения исполнения контракта в размере, превышающем в 1,5 раза размер обеспечения исполнения контракта, указанный в извещении, но не менее чем 10 процентов от начальной (максимальной) цены контракта или
# [108] txt:      таким участником обеспечения исполнения контракта в размере, превышающем в 1,5 раза размер обеспечения исполнения контракта, указанный в извещении, но не менее чем 10 процентов от начальной (максимальной) цены контракта
# [109] doc: 0.1. Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10 % ( __________ рублей) начальной (максимальной) цены контракта. В сл
# [109] txt:      Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10 % ( __________ рублей) начальной (максимальной) цены контракта.
# [110] doc: 9.1. Поставщик при заключении Договора должен предоставить Заказчику обеспечение исполнения Договора в размере ________________ рублей ____ копеек (5 % от цены Договора). В сл
# [110] txt:      Поставщик при заключении Договора должен предоставить Заказчику обеспечение исполнения Договора в размере ________________ рублей ____ копеек (5 % от цены Договора).
# [111] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [111] txt:      Размер обеспечения исполнения контракта 5.00%
# [112] doc: акта Размер обеспечения исполнения контракта 42000.00 Российский рубль Поря
# [112] txt:      Размер обеспечения исполнения контракта 42000.00 Российский рубль
# [113] doc: акта Размер обеспечения исполнения контракта 505.80 Российский рубль Поря
# [113] txt:      Размер обеспечения исполнения контракта 505.80 Российский рубль
# [114] doc: ьно. Сумма обеспечения исполнения договора составляет 10 % цены Договора, что составляет __________ (___________________) р
# [114] txt:      Сумма обеспечения исполнения договора составляет 10 % цены Договора, что составляет __________ (_________________
# [115] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [115] txt:      Размер обеспечения исполнения контракта 5.00%
# [116] doc: ого, как участник предоставит обеспечение исполнения Контракта в размере, в 1,5 раза превышающем размер обеспечения исполнения Контракта, указанный в п. 7.1.1 Контракта, но не менее 10% от начальной (максимальной) цены Контракта, или
# [116] txt:      как участник предоставит обеспечение исполнения Контракта в размере, в 1,5 раза превышающем размер обеспечения исполнения Контракта, указанный в п. 7.1.1 Контракта, но не менее 10% от начальной (максимальной) цены Контракта
# [117] doc: акта Размер обеспечения исполнения контракта 13087.50 Российский рубль Поря
# [117] txt:      Размер обеспечения исполнения контракта 13087.50 Российский рубль
# [118] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [118] txt:      Размер обеспечения исполнения контракта 5.00%
# [119] doc: акта Размер обеспечения исполнения контракта 17120.00 Российский рубль Поря
# [119] txt:      Размер обеспечения исполнения контракта 17120.00 Российский рубль
# [120] doc: акт, предоставляет заказчику до подписания контракта обеспечение исполнения контракта в размере 5 % начальной (максимальной) цены контракта. В сл
# [120] txt:      предоставляет заказчику до подписания контракта обеспечение исполнения контракта в размере 5 % начальной (максимальной) цены контракта.
# [121] doc: акта Размер обеспечения исполнения контракта 3000.01 Российский рубль Поря
# [121] txt:      Размер обеспечения исполнения контракта 3000.01 Российский рубль
# [122] doc: акта Размер обеспечения исполнения контракта 3493.80 Российский рубль Поря
# [122] txt:      Размер обеспечения исполнения контракта 3493.80 Российский рубль
# [123] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [123] txt:      Размер обеспечения исполнения контракта 10.00%
# [124] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [124] txt:      Размер обеспечения исполнения контракта 5.00%
# [125] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [125] txt:      Размер обеспечения исполнения контракта 5.00%
# [126] doc: акта Размер обеспечения исполнения контракта 44927.95 Российский рубль Поря
# [126] txt:      Размер обеспечения исполнения контракта 44927.95 Российский рубль
# [127] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [127] txt:      Размер обеспечения исполнения контракта 10.00%
# [128] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [128] txt:      Размер обеспечения исполнения контракта 5.00%
# [129] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [129] txt:      Размер обеспечения исполнения контракта 5.00%
# [130] doc: 9.1. Обеспечение исполнения Контракта установлено в размере 10 процентов от начальной (максимальной) цены контракта, и с
# [130] txt:      Обеспечение исполнения Контракта установлено в размере 10 процентов от начальной (максимальной) цены контракта
# [131] doc: акта Размер обеспечения исполнения контракта 113630.08 Российский рубль Поря
# [131] txt:      Размер обеспечения исполнения контракта 113630.08 Российский рубль
# [132] doc: 8.1. Обеспечение исполнения настоящего Контракта установлено в размере 5% от цены контракта и составляет _______ (________________________
# [132] txt:      Обеспечение исполнения настоящего Контракта установлено в размере 5% от цены контракта и составляет _______ (___________________
# [133] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [133] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [134] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [134] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [135] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [135] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [136] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [136] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [137] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [137] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [138] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [138] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [139] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [139] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [140] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [140] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [141] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [141] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [142] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [142] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [143] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [143] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [144] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [144] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [145] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [145] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [146] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [146] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [147] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [147] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [148] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [148] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [149] doc: жд». Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта с уч
# [149] txt:      Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# [150] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [150] txt:      Размер обеспечения исполнения контракта 5.00%
# [151] doc: акта Размер обеспечения исполнения контракта 9801.38 Российский рубль Поря
# [151] txt:      Размер обеспечения исполнения контракта 9801.38 Российский рубль
# [152] doc: акта Размер обеспечения исполнения контракта: 30% (тридцать процентов) от начальной (максимальной) це- ны контракта - 8
# [152] txt:      Размер обеспечения исполнения контракта: 30% (тридцать процентов) от начальной (максимальной) це- ны контракта
# [153] doc: акта Размер обеспечения исполнения контракта 32913.05 Российский рубль Поря
# [153] txt:      Размер обеспечения исполнения контракта 32913.05 Российский рубль
# [154] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [154] txt:      Размер обеспечения исполнения контракта 5.00%
# [155] doc: акта Размер обеспечения исполнения контракта 169932.36 Российский рубль Поря
# [155] txt:      Размер обеспечения исполнения контракта 169932.36 Российский рубль
# [156] doc: акта Размер обеспечения исполнения контракта 392456.00 Российский рубль Поря
# [156] txt:      Размер обеспечения исполнения контракта 392456.00 Российский рубль
# [157] doc: 2.1. Размер обеспечения исполнения Контракта составляет ______________рублей, что составляет 5 процентов от цены контракта, по которой заключается Контракт. Если
# [157] txt:      Размер обеспечения исполнения Контракта составляет ______________рублей, что составляет 5 процентов от цены контракта, по которой заключается Контракт.
# [158] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [158] txt:      Размер обеспечения исполнения контракта 10.00%
# [159] doc: 0.1. Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10,00 % начальной (максимальной) цены Контракта. В сл
# [159] txt:      Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10,00 % начальной (максимальной) цены Контракта.
# [160] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [160] txt:      Размер обеспечения исполнения контракта 10.00%
# [161] doc: акта Размер обеспечения исполнения контракта 43302.42 Российский рубль Поря
# [161] txt:      Размер обеспечения исполнения контракта 43302.42 Российский рубль
# [162] doc: 4.1. Размер обеспечения исполнения Контракта составляет 5 процентов цены Контракта в размере __________ (________) рублей ___ копе
# [162] txt:      Размер обеспечения исполнения Контракта составляет 5 процентов цены Контракта в размере __________ (________) рублей ___
# [163] doc: 4.1. Размер обеспечения исполнения Контракта составляет ______________рублей, что составляет 5 % процентов от цены контракта, по которой заключается Контракт. В сл
# [163] txt:      Размер обеспечения исполнения Контракта составляет ______________рублей, что составляет 5 % процентов от цены контракта, по которой заключается Контракт.
# [164] doc: 8.2. Размер обеспечения исполнения Контракта составляет 10 % начальной (максимальной) цены контракта, что
# [164] txt:      Размер обеспечения исполнения Контракта составляет 10 % начальной (максимальной) цены контракта
# [165] doc: 7.1. Обеспечение исполнения Контракта устанавливается в размере 5% цены контракта, что составляет ____________ (_____________) рубл
# [165] txt:      Обеспечение исполнения Контракта устанавливается в размере 5% цены контракта, что составляет ____________ (_____________)
# [166] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [166] txt:      Размер обеспечения исполнения контракта 5.00%
# [167] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [167] txt:      Размер обеспечения исполнения контракта 10.00%
# [168] doc: акта Размер обеспечения исполнения контракта 30.00% Поря
# [168] txt:      Размер обеспечения исполнения контракта 30.00%
# [169] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [169] txt:      Размер обеспечения исполнения контракта 10.00%
# [170] doc: акта Размер обеспечения исполнения контракта 3300.34 Российский рубль Поря
# [170] txt:      Размер обеспечения исполнения контракта 3300.34 Российский рубль
# [171] doc:  26. Размер обеспечения исполнения контракта 5 % начальной (максимальной) цены контракта 27.
# [171] txt:      Размер обеспечения исполнения контракта 5 % начальной (максимальной) цены контракта
# [172] doc:  26. Размер обеспечения исполнения контракта 5 % начальной (максимальной) цены контракта 27.
# [172] txt:      Размер обеспечения исполнения контракта 5 % начальной (максимальной) цены контракта
# [173] doc: 7.1. Размер обеспечения исполнения Контракта устанавливается в размере 10 % от цены, по которой заключается Контракт и составляет___________
# [173] txt:      Размер обеспечения исполнения Контракта устанавливается в размере 10 % от цены, по которой заключается Контракт и составляет______
# [174] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [174] txt:      Размер обеспечения исполнения контракта 5.00%
# [175] doc:  20. Размер обеспечения исполнения контракта 5% от цены контракта 21.
# [175] txt:      Размер обеспечения исполнения контракта 5% от цены контракта
# [176] doc:  20. Размер обеспечения исполнения контракта 5% от цены контракта 21.
# [176] txt:      Размер обеспечения исполнения контракта 5% от цены контракта
# [177] doc: 8.1. Обеспечение исполнения настоящего Контракта установлено в размере 10% от начальной (максимальной) цены контракта, что
# [177] txt:      Обеспечение исполнения настоящего Контракта установлено в размере 10% от начальной (максимальной) цены контракта
# [178] doc: 10.1 Размер обеспечения исполнения контракта: 5 % от цены контракта. В сл
# [178] txt:      Размер обеспечения исполнения контракта: 5 % от цены контракта.
# [179] doc: 8.4. Обеспечение исполнения настоящего Контракта устанавливается в размере 1 процент от начальной (максимальной) цены Контракта и составляет ____ (__
# [179] txt:      Обеспечение исполнения настоящего Контракта устанавливается в размере 1 процент от начальной (максимальной) цены Контракта и составляет ___
# [180] doc: 7.1. Обеспечение исполнения контракта устанавливается в размере 5% начальной (максимальной) цены контракта. 7.2.
# [180] txt:      Обеспечение исполнения контракта устанавливается в размере 5% начальной (максимальной) цены контракта.
# [181] doc: 8.1. Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10 (Десять) % начальной (максимальной) цены контракта. В сл
# [181] txt:      Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10 (Десять) % начальной (максимальной) цены контракта.
# [182] doc: 8.1. Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % начальной (максимальной) цены государственного контракта, что
# [182] txt:      Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % начальной (максимальной) цены государственного контракта
# [183] doc: акта Размер обеспечения исполнения контракта 24578.28 Российский рубль Поря
# [183] txt:      Размер обеспечения исполнения контракта 24578.28 Российский рубль
# [184] doc: 9.1. Обеспечение исполнения Контракта устанавливается в размере 10 процентов от начальной (максимальной) цены контракта. 9.2.
# [184] txt:      Обеспечение исполнения Контракта устанавливается в размере 10 процентов от начальной (максимальной) цены контракта.
# [185] doc: акта Размер обеспечения исполнения контракта 5 % от цены, по которой заключается контракт Поря
# [185] txt:      Размер обеспечения исполнения контракта 5 % от цены, по которой заключается контракт
# [186] doc: акта Размер обеспечения исполнения контракта 3851.21 Российский рубль Поря
# [186] txt:      Размер обеспечения исполнения контракта 3851.21 Российский рубль
# [187] doc: 7.1. Обеспечение исполнения Контракта устанавливается в размере 20% от максимального значения цены Контракта и со
# [187] txt:      Обеспечение исполнения Контракта устанавливается в размере 20% от максимального значения цены Контракта
# [188] doc: 6.1. Заказчиком установлено требование обеспечения исполнения Контракта - 5 % от цены Контракта, что составляет ​​​​​​​​​​​_____________ (ука
# [188] txt:      Заказчиком установлено требование обеспечения исполнения Контракта - 5 % от цены Контракта, что составляет ​​​​​​​​​​​_____________
# [189] doc: акта Размер обеспечения исполнения контракта 100.00% Поря
# [189] txt:      Размер обеспечения исполнения контракта 100.00%
# [190] doc: акта Размер обеспечения исполнения контракта 8900.00 Российский рубль Поря
# [190] txt:      Размер обеспечения исполнения контракта 8900.00 Российский рубль
# [191] doc: 9.1. Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10% от цены Контракт. В сл
# [191] txt:      Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10% от цены Контракт.
# [192] doc: акта Размер обеспечения исполнения контракта 1635.00 Российский рубль Поря
# [192] txt:      Размер обеспечения исполнения контракта 1635.00 Российский рубль
# [193] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [193] txt:      Размер обеспечения исполнения контракта 10.00%
# [194] doc: акта Размер обеспечения исполнения контракта 54517.53 Российский рубль Поря
# [194] txt:      Размер обеспечения исполнения контракта 54517.53 Российский рубль
# [195] doc: акта Размер обеспечения исполнения контракта 17389.85 Российский рубль Поря
# [195] txt:      Размер обеспечения исполнения контракта 17389.85 Российский рубль
# [196] doc: акта Размер обеспечения исполнения контракта 120711.45 Российский рубль Поря
# [196] txt:      Размер обеспечения исполнения контракта 120711.45 Российский рубль
# [197] doc: акта Размер обеспечения исполнения контракта 0.50% Поря
# [197] txt:      Размер обеспечения исполнения контракта 0.50%
# [198] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [198] txt:      Размер обеспечения исполнения контракта 10.00%
# [199] doc: кта: Размер обеспечения исполнения государственного контракта составляет 30 % от начальной (максимальной) цены контракта – 20
# [199] txt:      Размер обеспечения исполнения государственного контракта составляет 30 % от начальной (максимальной) цены контракта
# [200] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [200] txt:      Размер обеспечения исполнения контракта 10.00%
# [201] doc: а: - размер обеспечения исполнения контракта - 5 (пяти) процентов цены контракта. Испо
# [201] txt:      размер обеспечения исполнения контракта - 5 (пяти) процентов цены контракта.
# [202] doc: 9.1. Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10 % от начальной (максимальной) цены контракта и со
# [202] txt:      Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10 % от начальной (максимальной) цены контракта
# [203] doc: 2.1. Размер обеспечения исполнения Контракта составляет ______________рублей, что составляет 5 процентов от начальной (максимальной) цены Контракта. Если
# [203] txt:      Размер обеспечения исполнения Контракта составляет ______________рублей, что составляет 5 процентов от начальной (максимальной) цены Контракта.
# [204] doc: акта Размер обеспечения исполнения контракта 8536320.00 Российский рубль Поря
# [204] txt:      Размер обеспечения исполнения контракта 8536320.00 Российский рубль
# [205] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [205] txt:      Размер обеспечения исполнения контракта 10.00%
# [206] doc: 9.1. Обеспечение исполнения Контракта устанавливается в размере 5 процентов от Цены Контракта. 9.2.
# [206] txt:      Обеспечение исполнения Контракта устанавливается в размере 5 процентов от Цены Контракта.
# [207] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [207] txt:      Размер обеспечения исполнения контракта 5.00%
# [208] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [208] txt:      Размер обеспечения исполнения контракта 5.00%
# [209] doc: 1.1. Обеспечение исполнения Контракта устанавливается в размере - 1 % от цены Контракта, в с
# [209] txt:      Обеспечение исполнения Контракта устанавливается в размере - 1 % от цены Контракта
# [210] doc: 1.2. Размер обеспечения исполнения Контракта составляет 5% от цены Контракта. 11.3
# [210] txt:      Размер обеспечения исполнения Контракта составляет 5% от цены Контракта.
# [211] doc: -ФЗ) Размер обеспечения исполнения контракта по закупке: 5,00 % от начальной (максимальной) цены контракта, а и
# [211] txt:      Размер обеспечения исполнения контракта по закупке: 5,00 % от начальной (максимальной) цены контракта
# [212] doc: акта Размер обеспечения исполнения контракта 10.00% Поря
# [212] txt:      Размер обеспечения исполнения контракта 10.00%
# [213] doc: акт. Размер обеспечения исполнения Контракта составляет 30 % от цены Контракта указанной в пункте 2.1 Контракта, что
# [213] txt:      Размер обеспечения исполнения Контракта составляет 30 % от цены Контракта указанной в пункте 2.1 Контракта
# [214] doc: тся. Исполнитель внес обеспечение исполнения Контракта в размере ___ , что составляет 5 % максимального значения цены Контракта, пре
# [214] txt:      Исполнитель внес обеспечение исполнения Контракта в размере ___ , что составляет 5 % максимального значения цены Контракта
# [215] doc:  8.1.Обеспечение исполнения настоящего Контракта установлено в размере 10% от цены, по которой заключается контракт и составляет __________
# [215] txt:      Обеспечение исполнения настоящего Контракта установлено в размере 10% от цены, по которой заключается контракт и составляет _____
# [216] doc: акта Размер обеспечения исполнения контракта 5.00% Поря
# [216] txt:      Размер обеспечения исполнения контракта 5.00%
# [217] doc: 9.1. Размер обеспечения гарантийных обязательств по контракту предоставляется в размере _______ руб. (1 % от НМЦК). 9.2.
# [217] txt:      Размер обеспечения гарантийных обязательств по контракту предоставляется в размере _______ руб. (1 % от НМЦК).
# [218] doc: 8.1. Обеспечение исполнения настоящего Контракта установлено в размере 10,00 % от начальной (максимальной) цены Контракта. 8.2.
# [218] txt:      Обеспечение исполнения настоящего Контракта установлено в размере 10,00 % от начальной (максимальной) цены Контракта.
# [219] doc: 8.1. Обеспечение исполнения настоящего Контракта установлено в размере 10,00 % от начальной (максимальной) цены Контракта. 8.2.
# [219] txt:      Обеспечение исполнения настоящего Контракта установлено в размере 10,00 % от начальной (максимальной) цены Контракта.
# [220] doc: 9.1. Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % от цены Контракта. 9.2.
# ...
# [1683] txt:      Подрядчик обязан предоставить Заказчику обеспечение гарантийных обязательств на сумму ________ руб. (_______________ рублей __ копеек), что составляет 3 % от цены Договора, в форме _____________ (независимой гарантии или путем внесения денежных средств
# [1684] doc:  29. Размер обеспечения исполнения Договора и (или) обеспечения исполнения гарантийных обязательств, срок и порядок их предоставления Обеспечение исполнения Договора составляет - 15% от начальной (максимальной) цены Договора, что составляет 5 006 444 (Пят
# [1684] txt:      Размер обеспечения исполнения Договора и (или) обеспечения исполнения гарантийных обязательств, срок и порядок их предоставления Обеспечение исполнения Договора составляет - 15% от начальной (максимальной) цены Договора, что составляет 5 006 444
# [1686] doc: ств. Размер обеспечения исполнения гарантийных обязательств должен составлять не менее 20 % от начальной (максимальной) цены контракта или максимального значения цены договора (контракта). 10.7
# [1686] txt:      Размер обеспечения исполнения гарантийных обязательств должен составлять не менее 20 % от начальной (максимальной) цены контракта или максимального значения цены договора (контракта).
# [1691] doc: ств. Сумма обеспечения гарантийных обязательств предусмотрено в следующем размере: - 2 % от начальной (максимальной) цены договора, что составляет: 244 997,60 руб., НДС не облагается. 11.3
# [1691] txt:      Сумма обеспечения гарантийных обязательств предусмотрено в следующем размере: - 2 % от начальной (максимальной) цены договора, что составляет: 244 997,60 руб., НДС не облагается.
# [1692] doc: . 26 Размер обеспечения исполнения договора (или) гарантийных обязательств. Установлено в размере 5 (пяти) % от начальной максимальной цены Договора на сумму 90 200 (Девяносто тысяч двести) рублей 42 копейки. Обес
# [1692] txt:      Размер обеспечения исполнения договора (или) гарантийных обязательств. Установлено в размере 5 (пяти) % от начальной максимальной цены Договора на сумму 90 200 (Девяносто тысяч двести) рублей 42 копейки.
# [1693] doc: лено Размер обеспечения гарантийных обязательств составляет 5% от НМЦД- 65916,57 (Шестьдесят пять тысяч девятьсот шестнадцать) рублей 57 копеек. НДС не облагается. Раз
# [1693] txt:      Размер обеспечения гарантийных обязательств составляет 5% от НМЦД- 65916,57 (Шестьдесят пять тысяч девятьсот шестнадцать) рублей 57 копеек. НДС не облагается
# [1695] doc: жит. Поставщик может предоставить Покупателю в качестве обеспечения исполнения гарантийных обязательств безусловную и безотзывную банковскую гарантию на сумму равную не менее 5% (пять процентов) от стоимости работ. Пост
# [1695] txt:      Поставщик может предоставить Покупателю в качестве обеспечения исполнения гарантийных обязательств безусловную и безотзывную банковскую гарантию на сумму равную не менее 5% (пять процентов) от стоимости работ.
# [1696] doc: тв.] Размер обеспечения исполнения гарантийных обязательств составляет: _________0__________ рублей, НДС не облагается. Срок предоставления обеспечения исполнения гарантийных обязательств: _____________
# [1696] txt:      Размер обеспечения исполнения гарантийных обязательств составляет: _________0__________ рублей, НДС не облагается. Срок предоставления обеспечения исполнения гарантийных обязательств: ________
# [1698] doc: но): Размер обеспечения гарантийных обязательств: 1% от начальной (максимальной) цены контракта (договора), что составляет 24 992,34 рублей (двадцать четыре тысячи девятьсот девяносто два рубля 34 копейки). В сл
# [1698] txt:      Размер обеспечения гарантийных обязательств: 1% от начальной (максимальной) цены контракта (договора), что составляет 24 992,34 рублей (двадцать четыре тысячи девятьсот девяносто два рубля 34 копейки).
# [1701] doc: лен. Размер обеспечения гарантийных обязательств установлен в размере 20% от НМЦД: 1 644 839,76 рублей. Гарантийные обязательства обеспечиваются внесением денежных средств участником закупки на у
# [1701] txt:      Размер обеспечения гарантийных обязательств установлен в размере 20% от НМЦД: 1 644 839,76 рублей. Гарантийные обязательства обеспечиваются внесением денежных средств участником закупки
# [1702] doc: лен. Размер обеспечения гарантийных обязательств установлен в размере 20% от НМЦД: 1 644 839,76 рублей. Гарантийные обязательства обеспечиваются внесением денежных средств участником закупки на у
# [1702] txt:      Размер обеспечения гарантийных обязательств установлен в размере 20% от НМЦД: 1 644 839,76 рублей. Гарантийные обязательства обеспечиваются внесением денежных средств участником закупки
# [1710] doc: чику взамен ранее предоставленного обеспечения гарантийных обязательств новое обеспечение гарантийных обязательств. 9.4.
# [1710] txt:      взамен ранее предоставленного обеспечения гарантийных обязательств новое обеспечение гарантийных обязательств.
# [1715] doc: 6.2. Если договором предусмотрено предоставление обеспечения гарантийных обязательств, размер такого обеспечения может составлять от 0,01% до 10% от цены договора (лота) (максимального значения цены договора). 9.2.
# [1715] txt:      Если договором предусмотрено предоставление обеспечения гарантийных обязательств, размер такого обеспечения может составлять от 0,01% до 10% от цены договора (лота) (максимального значения цены договора).
# [1719] doc: ено. Предоставление Подрядчиком обеспечения гарантийных обязательств в размере 5 % от начальной (максимальной) цены Договора, что составляет что составляет 584 558 (Пят
# [1719] txt:      Предоставление Подрядчиком обеспечения гарантийных обязательств в размере 5 % от начальной (максимальной) цены Договора, что составляет что составляет 584 558
# [1720] doc: .11. Размер обеспечения гарантийных обязательств подрядчика устанавливается в размере 5% от начальной (максимальной) цены договора и составляет ___________. Офор
# [1720] txt:      Размер обеспечения гарантийных обязательств подрядчика устанавливается в размере 5% от начальной (максимальной) цены договора и составляет ___________.
# [1721] doc: 2.1. Размер обеспечения гарантийных обязательств по договору 1 (один) процент от общей цены договора. 12.2
# [1721] txt:      Размер обеспечения гарантийных обязательств по договору 1 (один) процент от общей цены договора.
# [1724] doc: . 14 Обеспечение гарантийных обязательств по Договору Устанавливается 5% от начальной максимальной цены договора- 22 500,00 (Двадцать две тысячи пятьсот) рублей 00 копеек. Требо
# [1724] txt:      Обеспечение гарантийных обязательств по Договору Устанавливается 5% от начальной максимальной цены договора- 22 500,00 (Двадцать две тысячи пятьсот) рублей 00 копеек.
# [1725] doc: ора. Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота). 2.10
# [1725] txt:      Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота).
# [1728] doc: я; - размер банковской гарантии на обеспечение гарантийных обязательств определяется не менее 5% (пяти процентов) от цены Договора в редакции Дополнительного соглашения; Раз
# [1728] txt:      размер банковской гарантии на обеспечение гарантийных обязательств определяется не менее 5% (пяти процентов) от цены Договора в редакции Дополнительного соглашения
# [1729] doc: ьств Сумма обеспечения исполнения гарантийных обязательств предусмотрена в следующем размере: 3 % от цены предложенной победителем закупки, НДС не облагается. Обес
# [1729] txt:      Сумма обеспечения исполнения гарантийных обязательств предусмотрена в следующем размере: 3 % от цены предложенной победителем закупки, НДС не облагается.
# [1731] doc: .13. Обеспечение гарантийных обязательств устанавливается в размере 10 процентов от начальной (максимальной) цены договора и составляет___________________________. 12.1
# [1731] txt:      Обеспечение гарантийных обязательств устанавливается в размере 10 процентов от начальной (максимальной) цены договора и составляет___________________________.
# [1732] doc: ром. Размер обеспечения гарантийных обязательств не может превышать 10 (десять) процентов НМЦД. 10.1
# [1732] txt:      Размер обеспечения гарантийных обязательств не может превышать 10 (десять) процентов НМЦД.
# [1734] doc: .13. Обеспечение гарантийных обязательств устанавливается в размере 10 процентов от начальной (максимальной) цены договора и составляет___________________________. 12.1
# [1734] txt:      Обеспечение гарантийных обязательств устанавливается в размере 10 процентов от начальной (максимальной) цены договора и составляет___________________________.
# [1738] doc: 1.2. Размер обеспечения гарантийных обязательств составляет 5% от цены Договора. Срок предоставления обеспечения гарантийных обязательств: до момента направления увед
# [1738] txt:      Размер обеспечения гарантийных обязательств составляет 5% от цены Договора. Срок предоставления обеспечения гарантийных обязательств: до момента направления
# [1742] doc: 29.1 Обеспечение возврата аванса и/или гарантийных обязательств: не установлено 30.
# [1742] txt:      Обеспечение возврата аванса и/или гарантийных обязательств: не установлено
# [1743] doc: 0500 Обеспечение исполнения договора №_______ на________ Требование об обеспечении исполнения гарантийных обязательств Устанавливается Размер обеспечения исполнения гарантийных обязательств: 5 % от начальной (максимальной) цены договора 8.4
# [1743] txt:      Обеспечение исполнения договора №_______ на________ Требование об обеспечении исполнения гарантийных обязательств Устанавливается Размер обеспечения исполнения гарантийных обязательств: 5 % от начальной (максимальной) цены договора
# [1744] doc: ора. Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота) и устанавливается в Специальной части. 1.8.
# [1744] txt:      Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота) и устанавливается в Специальной части.
# [1746] doc: рен. Сумма обеспечения гарантийных обязательств предусмотрено в следующем размере: - 2 % от начальной (максимальной) цены договора, что составляет: 189 989,80 руб., НДС не облагается. 11.3
# [1746] txt:      Сумма обеспечения гарантийных обязательств предусмотрено в следующем размере: - 2 % от начальной (максимальной) цены договора, что составляет: 189 989,80 руб., НДС не облагается.
# [1751] doc: . 28 Обеспечение гарантийных обязательств по договору ☒ Не требуется. ☐ Сумма обеспечения гарантийных обязательств по договору составляет 10% от цены договора. Обес
# [1751] txt:      Обеспечение гарантийных обязательств по договору ☒ Не требуется. ☐ Сумма обеспечения гарантийных обязательств по договору составляет 10% от цены договора.
# [1752] doc: исле НДС 20%, сборы и иные обязательные платежи, а также все расходы, связанные с обеспечением гарантийных обязательств. Нача
# [1752] txt:      НДС 20%, сборы и иные обязательные платежи, а также все расходы, связанные с обеспечением гарантийных обязательств.
# [1755] doc: ния. Размер обеспечения гарантийных обязательств не может превышать 10 процентов НМЦД. Обеспечение исполнения гарантийных обязательств может быть предоставлено поставщиком (исп
# [1755] txt:      Размер обеспечения гарантийных обязательств не может превышать 10 процентов НМЦД. Обеспечение исполнения гарантийных обязательств может быть предоставлено поставщиком
# [1760] doc: ьств Устанавливается Размер обеспечения исполнения гарантийных обязательств: 5 % от начальной (максимальной) цены договора 8.4
# [1760] txt:      Устанавливается Размер обеспечения исполнения гарантийных обязательств: 5 % от начальной (максимальной) цены договора
# [1764] doc: ора. Размер обеспечения исполнения гарантийных обязательств не может превышать 2% начальной (максимальной) цены договора (цены лота). 2.10
# [1764] txt:      Размер обеспечения исполнения гарантийных обязательств не может превышать 2% начальной (максимальной) цены договора (цены лота).
# [1767] doc: ора. Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота) и устанавливается в Специальной части. 1.8.
# [1767] txt:      Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота) и устанавливается в Специальной части.
# [1768] doc: ств. Сумма обеспечения гарантийных обязательств предусмотрено в следующем размере: - 2 % от начальной (максимальной) цены договора, что составляет: 213 991,00 руб., НДС не облагается. 11.3
# [1768] txt:      Сумма обеспечения гарантийных обязательств предусмотрено в следующем размере: - 2 % от начальной (максимальной) цены договора, что составляет: 213 991,00 руб., НДС не облагается.
# [1769] doc: 8.2. Обеспечение гарантийных обязательств устанавливается в размере 1 % начальной (максимальной) цены контракта. 8.3.
# [1769] txt:      Обеспечение гарантийных обязательств устанавливается в размере 1 % начальной (максимальной) цены контракта.
# [1771] doc: чику взамен ранее предоставленного обеспечения гарантийных обязательств новое обеспечение гарантийных обязательств. 9.4.
# [1771] txt:      взамен ранее предоставленного обеспечения гарантийных обязательств новое обеспечение гарантийных обязательств.
# [1773] doc: . 26 Размер обеспечения исполнения договора (или) гарантийных обязательств. Установлено в размере 5 (пяти) % от начальной максимальной цены Договора на сумму 58 769(Пять
# [1773] txt:      Размер обеспечения исполнения договора (или) гарантийных обязательств. Установлено в размере 5 (пяти) % от начальной максимальной цены Договора на сумму 58 769
# [1774] doc: шать срок действия гарантийных обязательств не менее чем на один месяц. Размер обеспечения Исполнение гарантийного обязательства по Контракту составляет 5% от начальной (максимальной) цены Контракта. Рекв
# [1774] txt:      срок действия гарантийных обязательств не менее чем на один месяц. Размер обеспечения Исполнение гарантийного обязательства по Контракту составляет 5% от начальной (максимальной) цены Контракта.
# [1778] doc: ора. Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота). В сл
# [1778] txt:      Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота).
# [1781] doc: ора. Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота) и устанавливается в Специальной части. 1.8.
# [1781] txt:      Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота) и устанавливается в Специальной части.
# [1786] doc: 2.1. Субподрядчик в качестве обеспечения надлежащего исполнения гарантийных обязательств по Договору предоставляет Подрядчику право на удержание в общем размере 2% от цены Договора (включая НДС), указанной в пункте 3.1. Договора (далее Гарантийное удержание). Гара
# [1786] txt:      Субподрядчик в качестве обеспечения надлежащего исполнения гарантийных обязательств по Договору предоставляет Подрядчику право на удержание в общем размере 2% от цены Договора (включая НДС), указанной в пункте 3.1. Договора (далее Гарантийное удержание).
# [1794] doc: если Заказчиком установлено требование обеспечения исполнения договора и (или) обеспечения исполнения гарантийных обязательств. 5% от начальной (максимальной) цены договора, что составляет 27450 (Два
# [1794] txt:      Заказчиком установлено требование обеспечения исполнения договора и (или) обеспечения исполнения гарантийных обязательств. 5% от начальной (максимальной) цены договора, что составляет 27450

# %% [markdown]
# ## Statistics and checks

# %% [markdown]
# To identify some statistics (number, top tokens, etc.), I will use popular NLP tools such as `natasha` and `spaCy`. Both python libraries have Russian language support and high scores on various NLP benchmarks. The default dictionaries, tokenizers, embeddings of words/sentences and models will be enough for counting and checking.
#
# We can immediately say due to the specifics of the task (formal documents, contracts):
# - The extracted text fragment is almost always a sentence or part of it
# - The extracted text fragment almost always contains words from the name of the label, numbers, % and currency mention

# %%
from natasha import Segmenter, Doc, NewsEmbedding
from collections import Counter
import spacy

# %%
PUNCTUATION_PATTERN = r"[%.,!:?\-\(\)«»\'\"_№/]"

# %%
# !python -q -m spacy download ru_core_news_lg
# Out:
# 2023-05-03 12:17:51.080726: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ru-core-news-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_lg-3.5.0/ru_core_news_lg-3.5.0-py3-none-any.whl (513.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.4/513.4 MB 2.0 MB/s eta 0:00:00
# Collecting pymorphy3>=1.0.0
#   Downloading pymorphy3-1.2.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from ru-core-news-lg==3.5.0) (3.5.2)
# Collecting pymorphy3-dicts-ru
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 34.5 MB/s eta 0:00:00
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.10/dist-packages (from pymorphy3>=1.0.0->ru-core-news-lg==3.5.0) (0.6.2)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pymorphy3>=1.0.0->ru-core-news-lg==3.5.0) (0.7.2)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (0.7.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (3.0.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (67.7.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (3.1.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (1.1.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (4.65.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (1.10.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (3.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (23.1)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (6.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (1.0.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (2.27.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (1.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (1.26.15)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->ru-core-news-lg==3.5.0) (2.1.2)
# Installing collected packages: pymorphy3-dicts-ru, pymorphy3, ru-core-news-lg
# Successfully installed pymorphy3-1.2.0 pymorphy3-dicts-ru-2.4.417150.4580142 ru-core-news-lg-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_lg')

# %%
emb = NewsEmbedding()
segmenter = Segmenter()

nlp = spacy.load("ru_core_news_lg", disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer", "ner"])
nlp.add_pipe("sentencizer")

multiple_annotations = False
ext_contains_quotes = False
tokens = []
tokens_spacy = []
tokens_e_spacy = []
sents = []
sents_spacy = []
words = Counter()
words_spacy = Counter()
ANSWER_WORDS = Counter()
answer_words_spacy = Counter()

for d in train + test:
  if 'extracted_part' in d:
    ext_text = d['extracted_part']['text'][0]
    if len(d['extracted_part']['text']) > 1:
      multiple_annotations = True
      print('Multiple annotations: ', d)
    if re.search(r'[\'|"|«].*?[\'|"|»]', ext_text):
      ext_contains_quotes = True
      print('Quotes: ', d)
    # natasha
    doc = Doc(ext_text)
    doc.segment(segmenter)
    ANSWER_WORDS.update([_.text for _ in doc.tokens])
    # spacy
    doc = nlp(ext_text)
    answer_words_spacy.update([_.text for _ in doc])
    # spacy for ext
    if d['extracted_part']['text'][0]:
      doc = nlp(d['extracted_part']['text'][0])
      tokens_e_spacy.append(len(doc))
  # natasha
  doc = Doc(d['text'])
  doc.segment(segmenter)
  tokens.append(len(doc.tokens))
  words.update([_.text for _ in doc.tokens])
  sents.append(len(doc.sents))
  # spacy
  doc = nlp(d['text'])
  tokens_spacy.append(len(doc))
  words_spacy.update([_.text for _ in doc])
  sents_spacy.append(len(list(doc.sents)))

print(f'Multiple annotations: {multiple_annotations}')
print(f'Quotes in answer: {ext_contains_quotes}')
print(f'Tokens natasha (number): max. {max(tokens)}, mean {sum(tokens)/len(tokens):.2f}, min. {min(tokens)}')
print(f'Tokens spacy (number): max. {max(tokens_spacy)}, mean {sum(tokens_spacy)/len(tokens_spacy):.2f}, min. {min(tokens_spacy)}')
print(f'Tokens extracted part spacy (number): max. {max(tokens_e_spacy)}, mean {sum(tokens_e_spacy)/len(tokens_e_spacy):.2f}, min. {min(tokens_e_spacy)}')
print(f'Sentences natasha (number): max. {max(sents)}, mean {sum(sents)/len(sents):.2f}, min. {min(sents)}')
print(f'Sentences spacy (number): max. {max(sents_spacy)}, mean {sum(sents_spacy)/len(sents_spacy):.2f}, min. {min(sents_spacy)}')

print(f'Топ 15 токенов natasha: {words.most_common(15)}')
print(f'Топ 15 токенов spacy: {words_spacy.most_common(15)}')
print(f'Топ токенов без пунктуации natasha: {[v for v in words.most_common(30) if not re.search(PUNCTUATION_PATTERN, v[0])]}')
print(f'Топ токенов без пунктуации spacy: {[v for v in words_spacy.most_common(30) if not re.search(PUNCTUATION_PATTERN, v[0])]}')
print(f'Топ 15 токенов в извлеченной части natasha: {ANSWER_WORDS.most_common(15)}')
print(f'Топ 15 токенов в извлеченной части spacy: {answer_words_spacy.most_common(15)}')
print(f'Топ токенов без пунктуации в извлеченной части natasha: {[v for v in ANSWER_WORDS.most_common(30) if not re.search(PUNCTUATION_PATTERN, v[0])]}')
print(f'Топ токенов без пунктуации в извлеченной части spacy: {[v for v in answer_words_spacy.most_common(30) if not re.search(PUNCTUATION_PATTERN, v[0])]}')
# Out:
# С кавычками:  {'id': 389142502, 'text': 'Общая часть 1. вки остановочных павильонов, утвержденном «Заказчиком». 1.15. Оценка качества работ проводится путем визуального осмотра поставленных и установленных остановочных павильонов представителями Заказчика и Поставщика. В случае выявления работы, не соответствующей требованиям, указанным в настоящем техническом задании, Заказчик направляет в адрес Поставщика предписание об устранении выявленных нарушений с указанием сроков их исполнения. Не выполнение предписания в установленные сроки влечет за собой применение к Поставщику штрафных санкций. 2. Объем и сроки предоставления гарантий качества поставляемого товара 2.1. Поставщик гарантирует качество поставляемого товара, функционирование объектов установки остановочных павильонов и входящих в них материалов и оборудования в соответствии с существующими стандартами, в течение 3 лет (с даты окончания срока поставки и установки остановочных павильонов), за исключением случаев повреждения установленных остановочных павильонов третьими лицами. 2.2. «Поставщик» обязан предоставить при сдаче-приемке остановочных павильонов обеспечение гарантийных обязательств по настоящему контракту в размере 1 % от начальной максимальной цены контракта, что составляет 6 976 (Шесть тысяч девятьсот семьдесят шесть) рублей 18 копеек. 3. Планируемые результаты поставки и установки Планируемыми результатами поставки и установки остановочных павильонов в городе Сарове является решение вопросов местного значения городского округа по созданию условий для предоставления транспортных услуг населению. 4. Лицо, осуществляющее контроль за ходом поставки и установки Для контроля за ходом поставки и установки от «Заказчика» назначается ответственный представитель – консультант сектора автотранспорта управления инженерной инфраструктуры и охраны окружающей среды Департамента городского хозяйства Администрации г.Саров Е.А.Волкова (т. 97768). Приложения: Приложение 1– Расчет начальной максимальной цены контракта на поставку и установку остановочных павильонов в городе Сарове Приложение 1 к техническому заданию Расчет начальной максимальной цены контракта на поставку и установку остановочных павильонов в городе Сарове Наименование Количество Коммерческое предложение 1 (вх. ЗАКАЗЧИК _____________________ м.п. ПОСТАВЩИК ____________________ м.п. Приложение 2 к муниципальному контракту от ___________ № ___________ Спецификация на поставку и установку остановочных павильонов в городе Сарове * № п/п Наименование Эскиз', 'label': 'обеспечение гарантийных обязательств', 'extracted_part': {'text': ['«Поставщик» обязан предоставить при сдаче-приемке остановочных павильонов обеспечение гарантийных обязательств по настоящему контракту в размере 1 % от начальной максимальной цены контракта, что составляет 6 976'], 'answer_start': [1015], 'answer_end': [1226]}}
# Несколько аннотаций: False
# Текст в кавычках в ответе: True
# Токены natasha (количество): макс. 1087, ср. 383.92, мин. 140
# Токены spacy (количество): макс. 918, ср. 375.35, мин. 134
# Токены извлеченной части spacy (количество): макс. 71, ср. 16.84, мин. 5
# Предложения natasha (количество): макс. 25, ср. 8.20, мин. 1
# Предложения spacy (количество): макс. 29, ср. 10.34, мин. 1
# Топ 15 токенов natasha: [('_', 95848), (',', 38996), ('.', 30885), ('в', 18836), (')', 12185), ('(', 11367), ('исполнения', 9751), ('обеспечения', 8053), ('на', 7964), ('с', 7827), ('и', 7711), ('"', 7127), (':', 6567), ('«', 6293), ('контракта', 6276)]
# Топ 15 токенов spacy: [('_', 93584), (',', 39213), ('.', 20063), ('в', 18807), (')', 11977), ('(', 11157), ('исполнения', 9750), ('обеспечения', 8052), ('на', 7984), ('с', 7745), ('и', 7685), ('"', 7121), ('«', 6287), ('контракта', 6143), ('№', 6096)]
# Топ токенов без пунктуации natasha: [('в', 18836), ('исполнения', 9751), ('обеспечения', 8053), ('на', 7964), ('с', 7827), ('и', 7711), ('контракта', 6276), ('договора', 5636), ('закупки', 5625), ('по', 5483), ('обязательств', 4780), ('от', 4653), ('не', 4411), ('о', 4315), ('к', 4141), ('соответствии', 3843), ('гарантии', 3642), ('гарантийных', 3268), ('г', 3268)]
# Топ токенов без пунктуации spacy: [('в', 18807), ('исполнения', 9750), ('обеспечения', 8052), ('на', 7984), ('с', 7745), ('и', 7685), ('контракта', 6143), ('договора', 5632), ('закупки', 5607), ('по', 5483), ('обязательств', 4775), ('от', 4650), ('не', 4412), ('о', 4259), ('к', 4135), ('соответствии', 3843), ('гарантии', 3642), ('гарантийных', 3268), ('или', 3245)]
# Топ 15 токенов в извлеченной части natasha: [('_', 2246), ('%', 1141), ('исполнения', 1046), (')', 1036), ('(', 1034), ('обеспечения', 1003), ('Размер', 930), ('цены', 924), ('от', 797), ('контракта', 720), ('договора', 694), ('начальной', 679), ('максимальной', 679), ('в', 604), ('обязательств', 542)]
# Топ 15 токенов в извлеченной части spacy: [('_', 2225), ('%', 1137), ('исполнения', 1046), (')', 1031), ('(', 1027), ('обеспечения', 1003), ('Размер', 930), ('цены', 923), ('от', 797), ('контракта', 720), ('договора', 694), ('начальной', 679), ('максимальной', 679), ('в', 604), ('обязательств', 542)]
# Топ токенов без пунктуации в извлеченной части natasha: [('исполнения', 1046), ('обеспечения', 1003), ('Размер', 930), ('цены', 924), ('от', 797), ('контракта', 720), ('договора', 694), ('начальной', 679), ('максимальной', 679), ('в', 604), ('обязательств', 542), ('гарантийных', 525), ('5', 522), ('размере', 453), ('составляет', 431), ('Контракта', 338), ('Обеспечение', 271), ('Российский', 258), ('рубль', 258), ('обеспечение', 249), ('устанавливается', 197), ('что', 183), ('Договора', 181)]
# Топ токенов без пунктуации в извлеченной части spacy: [('исполнения', 1046), ('обеспечения', 1003), ('Размер', 930), ('цены', 923), ('от', 797), ('контракта', 720), ('договора', 694), ('начальной', 679), ('максимальной', 679), ('в', 604), ('обязательств', 542), ('гарантийных', 525), ('5', 520), ('размере', 453), ('составляет', 430), ('Контракта', 337), ('Обеспечение', 271), ('Российский', 258), ('рубль', 258), ('обеспечение', 249), ('устанавливается', 197), ('что', 182), ('Договора', 181)]

# %% [markdown]
# It is not necessary to process several annotations (i.e. there are no overlapping annotations as well), which means that the task can be represented as finding named entities in the text. There is an idea to clean the text from the text in quotes, large numbers, underscores, but all this creates a problem with shifting the indexes of the extracted text fragment.
#
# The documents contain a large number of tokens (>512), so we will have to take this into account when training the model (the option to split the document creates a problem with the indexes of the extracted text fragment). Building an index of embeddings of document sentences will be very fast, since there are an average of 9 sentences in each document, which also means faster training of a transformer working with embeddings of sentences.
#
# The tops of the `natasha` and `spaCy` tokens differ quite slightly (I compared them for the sake of interest, because I'm going to use both tools). It can be seen that all the words from the label are in the top of the words of the document texts, which means that there may be several applications containing them in the documents, and we need to teach the model to identify exactly the fragment we need, for example, by adding more tokens for the label. To analyze this, I have compiled the top tokens in the extracted part and plan to use it to modify the embedding of the label. Also, at first glance, it seems that it is still worth including punctuation symbols (%, brackets) in the creation of the embedding of the label, because this is exactly what will help to identify the most appropriate text fragment in the document.

# %% [markdown]
# ## Label embeddings and search pattern

# %%
from natasha import Segmenter, Doc, NewsEmbedding, MorphVocab, NewsMorphTagger

# %%
emb = NewsEmbedding()
segmenter = Segmenter()
morph_vocab = MorphVocab()
morph_tagger = NewsMorphTagger(emb)


def emb_sentence(sentence):
  d = Doc(sentence)
  d.segment(segmenter)
  e = np.array([emb[token.text] for token in d.tokens if token.text in emb]).mean(axis=0)
  return e if e.shape == (EMB_DIM,) else None


def get_label_span_from_text(text, extracted_part):
  start = text.find(extracted_part)
  return start, start + len(extracted_part)

# %%
for label in LABELS:
  LABELS[label]['emb'] = emb_sentence(label)

  most_common_tokens = ' '.join([v[0] for v in ANSWER_WORDS.most_common(20) if not re.search(PUNCTUATION_PATTERN, v[0])])
  LABELS[label]['emb_tuned'] = emb_sentence(most_common_tokens)

  d = Doc(label)
  d.segment(segmenter)
  d.tag_morph(morph_tagger)
#           7.23696351e-02, -1.27074108e-01, -3.15127254e-01,  3.94654237e-02,
#           8.37920383e-02, -1.29082516e-01, -1.03509463e-01, -1.08910136e-01,
#           2.29065448e-01, -3.66016686e-01,  3.81503627e-02,  4.33849990e-01,
#          -1.45942032e-01,  1.23432115e-01,  1.97083399e-01, -1.37493730e-01,
#          -2.35178724e-01,  3.25711995e-01,  8.67897458e-03,  7.58125931e-02,
#          -3.53326499e-01,  2.25872040e-01, -1.54243708e-01,  9.53424037e-01,
#          -2.96255499e-01,  3.11510563e-02, -5.47188446e-02,  5.41838780e-02,
#           2.29128510e-01, -7.76230395e-02,  5.30083179e-02, -1.71543688e-01,
#           1.09210677e-01,  3.45172882e-01, -1.40156224e-01, -1.29443154e-01,
#          -8.65092427e-02, -7.20102806e-03,  2.47320518e-01,  2.06076801e-01,
#          -2.63768751e-02,  3.34365636e-01, -7.89651796e-02, -6.17112666e-02,
#           2.01868638e-01,  7.50006214e-02, -3.13683301e-01,  3.04876506e-01,
#          -1.79625645e-01,  1.80045620e-01,  2.15663463e-01, -1.21881351e-01,
#           8.57452974e-02,  4.32446823e-02,  3.73468757e-01,  2.56763518e-01,
#          -1.84046105e-01, -3.79284285e-02, -5.29161245e-02, -2.67551363e-01,
#          -2.29579821e-01,  1.41305923e-01, -5.68663627e-02, -7.55383447e-02,
#          -6.38777465e-02,  1.81933627e-01,  1.61511436e-01,  2.68564433e-01,
#          -7.37765953e-02,  1.87678337e-01,  2.39901036e-01,  7.51289679e-03,
#          -1.07731253e-01,  4.44462523e-02,  3.41899246e-02,  5.10407425e-03],
#         dtype=float32),
#   'regex_pattern': 'обеспечение|гарантийный|обязательство'}}

# %% [markdown]
# ## Statistics on extracted parts

# %%
from natasha import Segmenter, Doc, NewsEmbedding, MorphVocab, NewsMorphTagger


emb = NewsEmbedding()
segmenter = Segmenter()
morph_vocab = MorphVocab()
morph_tagger = NewsMorphTagger(emb)


def create_lemmatized_doc(text):
  d = Doc(text)
  d.segment(segmenter)
  d.tag_morph(morph_tagger)
  for token in d.tokens:
    token.lemmatize(morph_vocab)
  return d, ' '.join([token.lemma for token in d.tokens])


def search_for_direct_match(text, label):
  _, text_lemmatized = create_lemmatized_doc(text)
  matches = re.findall(LABELS[label]['regex_pattern'], text_lemmatized)

  return True if matches else False

# %%
from collections import Counter
from tqdm import tqdm


counter = Counter()
for d in tqdm(train):
    d_text = d['text']
    label = d['label']
    if search_for_direct_match(d_text, label):
        counter.update([label])
counter
# Out:
# 100%|██████████| 1799/1799 [01:47<00:00, 16.78it/s]
# Counter({'обеспечение исполнения контракта': 985,
#          'обеспечение гарантийных обязательств': 589})

# %%
for label in LABELS:
  overall_count = len([_ for _ in train if _['label'] == label])
  percent = counter[label]/overall_count * 100
  print(f'[{label}]: {counter[label]}/{overall_count} ({percent:.2f}%) have direct match of word from label in extracted part')
# Out:
# [обеспечение исполнения контракта]: 985/988 (99.70%) have direct match of word from label in extracted part
# [обеспечение гарантийных обязательств]: 589/811 (72.63%) have direct match of word from label in extracted part
